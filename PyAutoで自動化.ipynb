# %% [markdown]
# 使用モジュール <br>
# ・pygui <br>
# https://pyautogui.readthedocs.io/en/latest/ <br>
# ・time

# %%
import pyautogui as pgui
import time

# %% [markdown]
# マウスの現在位置の取得

# %%
pgui.position()
# Out:
# Point(x=515, y=317)

# %% [markdown]
# # 画面全体のサイズを取得する

# %%
pgui.size()
# Out:
# Size(width=1920, height=1080)

# %% [markdown]
# # クリックの自動化:pgui.click()が動かなければシステムのアクセス許可が降りていない可能性がある。

# %%
pgui.click()

# %% [markdown]
# click関数の説明を追加

# %%
pgui.click(x=515, y=317, duration=1)

# %% [markdown]
# # スクリーンショットを撮る

# %%
pgui.screenshot('sample.png')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x25CCA881730>

# %% [markdown]
# # 範囲を指定してスクリーンショットを撮る

# %%
pgui.screenshot('sample.png', region=(0, 200, 300, 300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x25CCAC47D30>

# %% [markdown]
# # PyAutoGUIのFailSafe機能
# FailSafe機能を有効にしておくと
# プログラムの緊急停止:マウスカーソルを座標に(0,0)を持っていく

# %%
pgui.FAILSAFE = True
